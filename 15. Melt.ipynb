# %% [markdown]
# ![cover](cover/15.%20Melt%20Function.png)

# %% [markdown]
# #### Outline
# * Frame
# * ID Vars
# * Value Vars
# * Var Name
# * Value Name

# %% [markdown]
# ### Melt
#
# Description

# %% [markdown]
# ##### Import Pandas

# %%
import pandas

# %% [markdown]
# ##### Import Datasets

# %%
# import data set(s)

# %% [markdown]
# ### Melt
#
# `syntax`
#
# description

# %% [markdown]
# ### For Source code:
# https://sites.google.com/view/aorbtech/programming/
#
# #### @Aorb Tech
