# %% [markdown]
# ![cover](cover/10.%20GroupBy%20Function.png)

# %% [markdown]
# #### Outline
# * GroupBy
# * Set Group

# %% [markdown]
# ##### Import Pandas

# %% [markdown]
# ### groupby
#
# `groupby(by = '')`
#
# Splits data into groups

# %% [markdown]
# ### get_group
#
# `groupby().get_group(n)`
#
# Sets given values to group entries

# %% [markdown]
# ### For Source code:
# https://sites.google.com/view/aorbtech/programming/
#
# #### @Aorb Tech
