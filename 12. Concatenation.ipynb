# %% [markdown]
# ![cover](cover/12.%20Concatenation.png)

# %% [markdown]
# #### Outline
#
# * Concat Function
# * Ignore Index
# * Axis
# * Join
#   * Inner
#   * Outer
# * Keys
# * Sort

# %% [markdown]
# ### Concatenation
#
# This function allows us to stack, or merge, multiple pandas objects, such as series and dataframes, into a single object. Below is a diagram demonstrating how two objects can be stacked/merged into a single object, depending on the `axis` parameter:

# %% [markdown]
# **figure 1**
#
# *concat() function demonstration*
#
# ![cover](diagrams/concat_axis.png)
#
# *A diagram depicting the concat() function applied to two objects, teal and liver-grey, on axis' 0 and 1*

# %% [markdown]
# ##### Import Pandas

# %%
import pandas

# %% [markdown]
# ##### Import Datasets

# %%
students = pandas.read_csv('./datasets/students.csv')
language_learners = pandas.read_csv('./datasets/language_learners.csv')

# %% [markdown]
# ### concat()
#
# `pandas.concat([a,b,...,n])`
#
# This function allows us to merge multiple pandas objects, such as series or dataframes, into a single object
#
# * Series
# * DataFrame

# %% [markdown]
# ### For Source code:
# https://sites.google.com/view/aorbtech/programming/
#
# #### @Aorb Tech
